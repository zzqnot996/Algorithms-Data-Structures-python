# %% [markdown]
# <a href="https://colab.research.google.com/github/zzqnot996/coding/blob/main/%E5%8D%95%E5%90%91%E9%93%BE%E8%A1%A8_%E6%B7%BB%E5%8A%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class SingleNode(object):
  # 单链表的结点”
  def __init__(self,item):
    # item存放数据元素
    self.item = item
    # next是下一个节点的标识
    self.next = None


class SingleLinkList:
  def __init__(self):
    self.__head: SingleNode  = None
    # - is_empty() 链表是否为空
    # - Length() 链表长度

  # - traveL() 遍历整个链表
  def travel(self):
    cur: SingleNode = self.__head
    while cur is not None:
      print(cur.item,end = "\t")
      cur = cur.next
    print("")



  # - add(item) 链表头部添加元素
  def add(self,item):
    node = SingleNode(item)
    node.next = self.__head
    self.__head = node

  # - append(item) 链表尾部添加元素
  def append(self,item):
    node = SingleNode(item)
    # 如果最后结尾没有节点 新添加的直接指向该节点
    if self.__head is None:
      self.__head = node
    # 如果有该节点
    else:
      # 遍历
      cur = self.__head
      while cur.next is not None:
        cur = cur.next # 获取最后一个节点
      cur.next = node

    # - insert(pos，item) 指定位置添加元素
    # - remove(item) 删除节点
    # - search(item) 查找节点是否存在

if __name__ == "__main__":

    single_link_list = SingleLinkList()
    single_link_list.add("元素1")
    single_link_list.add("元素2")
    single_link_list.add("元素3")
    single_link_list.append("元素4")
    single_link_list.append("元素5")
    single_link_list.travel()
# Out:
# 元素3	元素2	元素1	元素4	元素5

# %% [markdown]
# ![image.png](data:image/png;base64,...)
